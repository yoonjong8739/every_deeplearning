# %% [markdown]
# ### 실습 | 폐암 수술 환자의 생존율 예측하기

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

Data_set = np.loadtxt('./data/ThoraricSurgery3.csv', delimiter=",")

X = Data_set[:, 0:16]  # 환자의 진찰 기록
y = Data_set[:, 16]    # 생존여부

model = Sequential()
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X, y, epochs=5, batch_size=16)
# Out:
# Epoch 1/5
# 30/30 [==============================] - 2s 3ms/step - loss: 2.3872 - acc: 0.4085
# Epoch 2/5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5609 - acc: 0.8511
# Epoch 3/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4895 - acc: 0.8511
# Epoch 4/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4728 - acc: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4621 - acc: 0.8511

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

loss = history.history['loss']
acc = history.history['acc']
epoch = range(len(acc))

plt.figure(figsize=(12,8))

plt.subplot(1,2,1)
plt.plot(epoch, loss, 'r:', label='loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(epoch, acc, 'b--', label='acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show();
